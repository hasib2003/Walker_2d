# %%
# !pip install stable-baselines3[extra] gymnasium[mujoco] rl_zoo3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.2/77.2 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 37.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 39.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 61.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.8/92.8 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 2.7 MB/s eta 0:00:00
# ...

# %%
# !rl_zoo3 train --algo a2c --env Walker2d-v4 --hyperparams n_envs:4 -i /content/drive/MyDrive/RL_Checkpoints/logs/a2c/Walker2d-v4_2/Walker2d-v4.zip --log-folder /content/drive/MyDrive/RL_Checkpoints/logs --tensorboard-log /content/drive/MyDrive/RL_Checkpoints/t_logs
# Out:
# Streaming output truncated to the last 5000 lines.
# |    fps                | 1064     |
# |    iterations         | 23800    |
# |    time_elapsed       | 447      |
# |    total_timesteps    | 476000   |
# | train/                |          |
# |    entropy_loss       | -7.42    |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 73799    |
# |    policy_loss        | -0.0363  |
# |    std                | 0.862    |
# |    value_loss         | 0.0093   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 402      |
# |    ep_rew_mean        | 1.13e+03 |
# | time/                 |          |
# |    fps                | 1065     |
# |    iterations         | 23900    |
# |    time_elapsed       | 448      |
# |    total_timesteps    | 478000   |
# | train/                |          |
# |    entropy_loss       | -7.43    |
# ...

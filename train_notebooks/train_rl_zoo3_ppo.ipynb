# %%
# !pip install stable-baselines3[extra] gymnasium[mujoco] rl_zoo3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.2/77.2 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 40.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 56.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 75.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 32.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.8/92.8 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 21.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 8.2 MB/s eta 0:00:00
# ...

# %%
# python train.py --algo a2c --env BreakoutNoFrameskip-v4 -i rl-trained-agents/a2c/BreakoutNoFrameskip-v4_1/BreakoutNoFrameskip-v4.zip -n 5000

# %%
# !rl_zoo3 train --algo ppo --env Walker2d-v4 --hyperparams n_envs:4 -i /content/drive/MyDrive/RL_Checkpoints/logs/ppo/Walker2d-v4_1/best_model.zip --log-folder /content/drive/MyDrive/RL_Checkpoints/logs
# Out:
# Streaming output truncated to the last 5000 lines.
# |    iterations           | 166          |
# |    time_elapsed         | 1271         |
# |    total_timesteps      | 339968       |
# | train/                  |              |
# |    approx_kl            | 0.0060537816 |
# |    clip_fraction        | 0.271        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.41        |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 5.05e-05     |
# |    loss                 | -0.0231      |
# |    n_updates            | 14703        |
# |    policy_gradient_loss | -0.0216      |
# |    std                  | 0.434        |
# |    value_loss           | 0.00696      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 788         |
# |    ep_rew_mean          | 3.23e+03    |
# | time/                   |             |
# ...

# %%
# !zip -r /content/logs_latest.zip /content/logs
# Out:
#   adding: content/logs/ (stored 0%)
#   adding: content/logs/ppo/ (stored 0%)
#   adding: content/logs/ppo/Walker2d-v4_4/ (stored 0%)
#   adding: content/logs/ppo/Walker2d-v4_4/0.monitor.csv (deflated 50%)
#   adding: content/logs/ppo/Walker2d-v4_4/best_model.zip (stored 0%)
#   adding: content/logs/ppo/Walker2d-v4_4/3.monitor.csv (deflated 50%)
#   adding: content/logs/ppo/Walker2d-v4_4/evaluations.npz (deflated 49%)
#   adding: content/logs/ppo/Walker2d-v4_4/Walker2d-v4.zip (stored 0%)
#   adding: content/logs/ppo/Walker2d-v4_4/1.monitor.csv (deflated 50%)
#   adding: content/logs/ppo/Walker2d-v4_4/2.monitor.csv (deflated 50%)
#   adding: content/logs/ppo/Walker2d-v4_4/Walker2d-v4/ (stored 0%)
#   adding: content/logs/ppo/Walker2d-v4_4/Walker2d-v4/vecnormalize.pkl (deflated 35%)
#   adding: content/logs/ppo/Walker2d-v4_4/Walker2d-v4/config.yml (deflated 49%)
#   adding: content/logs/ppo/Walker2d-v4_4/Walker2d-v4/args.yml (deflated 62%)
# ...

# %%
# !ls
# Out:
# drive  logs  logs.zip  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
